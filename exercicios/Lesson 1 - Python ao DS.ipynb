# %% [markdown]
# # Lauch Application

# %%
import pandas as pd
doc = pd.read_csv('datasets/kc_house_data.csv')
doc.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # Questions | Answers - lesson one

# %% [markdown]
# ### 1. Quantas casas estão disponíveis para compra?

# %%
doc.shape
# Out:
# (21613, 21)

# %% [markdown]
# 21.613 casas disponíveis para compra.

# %% [markdown]
# ### 2. Quantos atributos as casas possuem?

# %%
doc.shape
# Out:
# (21613, 21)

# %% [markdown]
# As casas possuem 21 atributos.

# %% [markdown]
# ### 3. Quais são os atributos das casas?

# %%
doc.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# ### 4. Qual a casa mais cara ( casa com o maior valor de venda )?

# %%
doc.sort_values('price', ascending= False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %% [markdown]
# A casa mais caro id: 6762700020, valor: 7700000.0$

# %% [markdown]
# ### 5. Qual a casa com o maior número de quartos?

# %%
doc.sort_values('bedrooms', ascending= False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# ...           ...              ...        ...       ...        ...
# 19452  3980300371  20140926T000000   142000.0         0       0.00
# 8484   2310060040  20140925T000000   240000.0         0       2.50
# 875    6306400140  20140612T000000  1095000.0         0       0.00
# 8477   2569500210  20141117T000000   339950.0         0       2.50
# 9773   3374500520  20150429T000000   355000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %% [markdown]
# A casa com o id: 2402100895 tem o maior número de quartos. Total de 33 quartos.

# %% [markdown]
# ### 6. Qual a soma total de quartos do conjunto de dados?

# %%
doc.bedrooms.sum()
# Out:
# 72854

# %% [markdown]
# A soma total do conjunto de dados é: 72.854 quartos.

# %% [markdown]
# ### 7. Quantas casas possuem 2 banheiros?

# %%
doc[doc['bathrooms'] == 2].shape
# Out:
# (1930, 21)

# %% [markdown]
# 1930 casas possuem dois banheiros.

# %% [markdown]
# ### 8. Qual o preço médio de todas as casas no conjunto de dados?

# %%
print(f'{doc.price.mean():0.2f}')
# Out:
# 540088.14

# %% [markdown]
# O preço médio das casas no conjunto de dados é: 540088.14$

# %% [markdown]
# ### 9. Qual o preço médio de casas com 2 banheiros?

# %%
list_doc_1 = doc.loc[doc.bathrooms == 2]
print(f'{list_home_1.price.mean():.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0430fd62186c> in <module>
#       1 list_doc_1 = doc.loc[doc.bathrooms == 2]
# ----> 2 print(f'{list_home_1.price.mean():.2f}')
#
# NameError: name 'list_home_1' is not defined

# %% [markdown]
# O preço médio das casas com dois banheiro é: 457889.72$

# %% [markdown]
# ### 10. Qual o preço mínimo entre as casas com 3 quartos?

# %%
list_doc_2 = doc.loc[doc.bedrooms == 3]
list_doc_2.price.min()

# %% [markdown]
# 82.000.00$ é o menor preço das casas com três quartos.

# %% [markdown]
# ### 11. Quantas casas possuem mais de 300 metros quadrados na sala de estar?

# %%
# OBS: 1 pé quadrado = 0.092
doc.m2_living = doc.sqft_living * 0.092
doc[doc['m2_living']> 300].shape

# %% [markdown]
# 2141 casas possuem mais de 300m².

# %% [markdown]
# ### 12. Quantas casas tem mais de 2 andares?

# %%
doc[doc['floors'] > 2].shape

# %% [markdown]
# 782 casas tem mais de dois andares

# %% [markdown]
# ### 13. Quantas casas tem vista para o mar?

# %%
doc[doc['waterfront'] > 0].shape

# %% [markdown]
# 163 casas tem vista para o mar.

# %% [markdown]
# ### 14. Das casas com vista para o mar, quantas tem 3 quartos?

# %%
list_doc_3 = doc[doc['waterfront'] > 0]
list_doc_3[list_doc_3['bedrooms'] > 3].shape

# %% [markdown]
# 63 casas com vista para o mar tem três quartos.

# %% [markdown]
# ### 15. Das casas com mais de 300 metros quadrados de sala de estar, quantas tem mais de 2 banheiros?

# %%
# list_doc_4 = doc[doc['m2_living'] > 300]
# list_doc_4[list_doc_4['bathrooms'] > 2].shape
doc[( doc['m2_living'] > 300) & (doc['bathrooms'] > 2)].shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'm2_living'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-c9fbbb2a06a6> in <module>
# ...

# %% [markdown]
# 2088 casas com mais de 300m² possuem mais de dois banheiros.
